# %% [markdown]
# In this tutorial we will see how to add column or rows in Data Frame

# %%
import pandas as pd

# %%
df = pd.read_json("095 supermarkets.json")

# %%
df
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df.set_index("Address", inplace=True)

# %%
df
# Out:
#                  ID           City             State Country         Name  \
# Address
# 3666 21st St      1  San Francisco          CA 94114     USA      Madeira
# 735 Dolores St    2  San Francisco          CA 94119     USA  Bready Shop
# 332 Hill St       3  San Francisco  California 94114     USA  Super River
# 3995 23rd St      4  San Francisco          CA 94114     USA   Ben's Shop
# 1056 Sanchez St   5  San Francisco        California     USA      Sanchez
# 551 Alvarado St   6  San Francisco          CA 94114     USA   Richvalley
#
#                  Employees
# Address
# 3666 21st St             8
# 735 Dolores St          15
# 332 Hill St             25
# 3995 23rd St            10
# 1056 Sanchez St         12
# 551 Alvarado St         20

# %%
len(df.index)
# Out:
# 6

# %%
df["Continent"] = ["Africa","Asia","North America", "South America","Jack", "Beacn"]

# %%
df
# Out:
#                  ID           City             State Country         Name  \
# Address
# 3666 21st St      1  San Francisco          CA 94114     USA      Madeira
# 735 Dolores St    2  San Francisco          CA 94119     USA  Bready Shop
# 332 Hill St       3  San Francisco  California 94114     USA  Super River
# 3995 23rd St      4  San Francisco          CA 94114     USA   Ben's Shop
# 1056 Sanchez St   5  San Francisco        California     USA      Sanchez
# 551 Alvarado St   6  San Francisco          CA 94114     USA   Richvalley
#
#                  Employees      Continent
# Address
# 3666 21st St             8         Africa
# 735 Dolores St          15           Asia
# 332 Hill St             25  North America
# 3995 23rd St            10  South America
# 1056 Sanchez St         12           Jack
# 551 Alvarado St         20          Beacn

# %% [markdown]
# Modifying a column

# %%
df["Continent"] = df["Country"] + "," + " America"

# %%
df
# Out:
#                  ID           City             State Country         Name  \
# Address
# 3666 21st St      1  San Francisco          CA 94114     USA      Madeira
# 735 Dolores St    2  San Francisco          CA 94119     USA  Bready Shop
# 332 Hill St       3  San Francisco  California 94114     USA  Super River
# 3995 23rd St      4  San Francisco          CA 94114     USA   Ben's Shop
# 1056 Sanchez St   5  San Francisco        California     USA      Sanchez
# 551 Alvarado St   6  San Francisco          CA 94114     USA   Richvalley
#
#                  Employees     Continent
# Address
# 3666 21st St             8  USA, America
# 735 Dolores St          15  USA, America
# 332 Hill St             25  USA, America
# 3995 23rd St            10  USA, America
# 1056 Sanchez St         12  USA, America
# 551 Alvarado St         20  USA, America

# %% [markdown]
# ------------

# %% [markdown]
# Adding a new row in data frame

# %%
df1 = df.T

# %%
df1
# Out:
# Address     3666 21st St 735 Dolores St       332 Hill St   3995 23rd St  \
# ID                     1              2                 3              4
# City       San Francisco  San Francisco     San Francisco  San Francisco
# State           CA 94114       CA 94119  California 94114       CA 94114
# Country              USA            USA               USA            USA
# Name             Madeira    Bready Shop       Super River     Ben's Shop
# Employees              8             15                25             10
# Continent   USA, America   USA, America      USA, America   USA, America
#
# Address   1056 Sanchez St 551 Alvarado St
# ID                      5               6
# City        San Francisco   San Francisco
# State          California        CA 94114
# Country               USA             USA
# Name              Sanchez      Richvalley
# Employees              12              20
# Continent    USA, America    USA, America

# %% [markdown]
# Use same syntax as above to add new values and modifying them

# %%
df1["haseeb shaheed colony"] = [44,"texas","T","USA","Jack",16,"USA, America"]

# %%
df = df1.T

# %%
df
# Out:
#                        ID           City             State Country  \
# Address
# 3666 21st St            1  San Francisco          CA 94114     USA
# 735 Dolores St          2  San Francisco          CA 94119     USA
# 332 Hill St             3  San Francisco  California 94114     USA
# 3995 23rd St            4  San Francisco          CA 94114     USA
# 1056 Sanchez St         5  San Francisco        California     USA
# 551 Alvarado St         6  San Francisco          CA 94114     USA
# haseeb shaheed colony  44          texas                 T     USA
#
#                               Name Employees     Continent
# Address
# 3666 21st St               Madeira         8  USA, America
# 735 Dolores St         Bready Shop        15  USA, America
# 332 Hill St            Super River        25  USA, America
# 3995 23rd St            Ben's Shop        10  USA, America
# 1056 Sanchez St            Sanchez        12  USA, America
# ...
